# %%
import numpy as np
import neurolab as nl
import pylab as pl

fig_size = pl.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 10
pl.rcParams["figure.figsize"] = fig_size

# %%
#Количество классов
n = 4

x = np.array([[1., 5.], [2., 6.], [4., 4.], [5., 6.], [6., 3.], [6., 5.], [2., 3.], [3., 3.], [3., 1.], [7., 1.], [8., 2.], [8., 4.]])

# %%
net = nl.net.newc([[0.0, 10.0],[0.0, 10.0]], 4)
error = net.train(x, epochs=200, show=20)
# Out:
# Epoch: 20; Error: 17.572283169163292;
# Epoch: 40; Error: 17.33819798897287;
# Epoch: 60; Error: 17.259552874387843;
# Epoch: 80; Error: 17.26876195658809;
# Epoch: 100; Error: 17.26638589052238;
# Epoch: 120; Error: 17.26320447166958;
# Epoch: 140; Error: 17.261069699953804;
# Epoch: 160; Error: 17.259865541901274;
# Epoch: 180; Error: 17.25923518456574;
# Epoch: 200; Error: 17.258917644779707;
# The maximum number of train epochs is reached

# %%
w = net.layers[0].np['w'] #центры
pl.plot(x[:,0], x[:,1], 'b+', w[:,0], w[:,1], 'ro')
pl.legend(['train samples','centers'])
pl.show()
