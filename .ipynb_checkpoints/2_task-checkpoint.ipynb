# %%
import neurolab as nl
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
matplotlib.style.use('ggplot')
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size

# %%
n=20
x1 = np.linspace(0, 5, n).reshape(n, 1)
x2 = np.linspace(0, 5, n).reshape(n, 1)
final_y = np.empty(n)

for i in range(n):
    if x2[i] - x1[i]**2 + 4*x1[i] - 5 > 0:
        final_y[i] = 1
    elif x2[i] - x1[i]**2 + 4*x1[i] - 5 < 0:
        final_y[i] = -1
final_y = final_y.reshape(n, 1)
# Out:
# array([[ 0.        ],
#        [ 0.26315789],
#        [ 0.52631579],
#        [ 0.78947368],
#        [ 1.05263158],
#        [ 1.31578947],
#        [ 1.57894737],
#        [ 1.84210526],
#        [ 2.10526316],
#        [ 2.36842105],
#        [ 2.63157895],
#        [ 2.89473684],
#        [ 3.15789474],
#        [ 3.42105263],
#        [ 3.68421053],
#        [ 3.94736842],
#        [ 4.21052632],
#        [ 4.47368421],
#        [ 4.73684211],
#        [ 5.        ]])

# %%
net = nl.net.newff([[0, 5], [0, 5]],[5, 1])

error = net.train([x1, x2], final_y, epochs=500, show=100, goal=0.02)

# Simulate network
out = net.sim(x)
out
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-61-30617e35683a> in <module>()
#       1 net = nl.net.newff([[0, 5], [0, 5]],[5, 1])
#       2
# ----> 3 error = net.train([x1, x2], final_y, epochs=500, show=100, goal=0.02)
#       4
#       5 # Simulate network
#
# /Users/Dmitry/anaconda3/envs/data_science_test/lib/python3.6/site-packages/neurolab/core.py in train(self, *args, **kwargs)
#     163
#     164         """
# --> 165         return self.trainf(self, *args, **kwargs)
#     166
#     167     def reset(self):
#
# /Users/Dmitry/anaconda3/envs/data_science_test/lib/python3.6/site-packages/neurolab/core.py in __call__(self, net, input, target, **kwargs)
#     320         input = np.asfarray(input)
#     321         assert input.ndim == 2
# --> 322         assert input.shape[1] == net.ci
#     323         args.append(input)
# ...

# %%
for i in range(n):
    if -1.1 < out[i] < -0.9:
        plt.plot(x[i, 0], x[i, 1], 'go')
    if 0.9 < out[i] < 1.1:
        plt.plot(x[i,0], x[i, 1], 'bo')

# %%
b = x1[:]**2 - 4*x1[:] + 5

plt.plot(x1[:], b)

plt.show()
